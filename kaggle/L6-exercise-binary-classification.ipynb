# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt

#plt.style.use('seaborn-whitegrid')
import seaborn as sns
sns.set_style('whitegrid')

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('./datasets/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)
# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 5s 16ms/step - loss: 0.4856 - binary_accuracy: 0.7698 - val_loss: 0.4444 - val_binary_accuracy: 0.8059
# Epoch 2/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.4226 - binary_accuracy: 0.8027 - val_loss: 0.4025 - val_binary_accuracy: 0.8142
# Epoch 3/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4102 - binary_accuracy: 0.8072 - val_loss: 0.3944 - val_binary_accuracy: 0.8173
# Epoch 4/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4015 - binary_accuracy: 0.8132 - val_loss: 0.3904 - val_binary_accuracy: 0.8182
# Epoch 5/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3976 - binary_accuracy: 0.8154 - val_loss: 0.3854 - val_binary_accuracy: 0.8215
# Epoch 6/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3941 - binary_accuracy: 0.8166 - val_loss: 0.3835 - val_binary_accuracy: 0.8232
# Epoch 7/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3906 - binary_accuracy: 0.8190 - val_loss: 0.3822 - val_binary_accuracy: 0.8234
# Epoch 8/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3868 - binary_accuracy: 0.8200 - val_loss: 0.3795 - val_binary_accuracy: 0.8268
# Epoch 9/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3833 - binary_accuracy: 0.8235 - val_loss: 0.3743 - val_binary_accuracy: 0.8268
# Epoch 10/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3800 - binary_accuracy: 0.8236 - val_loss: 0.3743 - val_binary_accuracy: 0.8263
# Epoch 11/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3781 - binary_accuracy: 0.8251 - val_loss: 0.3737 - val_binary_accuracy: 0.8252
# Epoch 12/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3755 - binary_accuracy: 0.8267 - val_loss: 0.3688 - val_binary_accuracy: 0.8299
# Epoch 13/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3734 - binary_accuracy: 0.8271 - val_loss: 0.3696 - val_binary_accuracy: 0.8301
# Epoch 14/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3708 - binary_accuracy: 0.8282 - val_loss: 0.3642 - val_binary_accuracy: 0.8326
# Epoch 15/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3695 - binary_accuracy: 0.8292 - val_loss: 0.3635 - val_binary_accuracy: 0.8343
# Epoch 16/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3668 - binary_accuracy: 0.8313 - val_loss: 0.3638 - val_binary_accuracy: 0.8330
# Epoch 17/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3646 - binary_accuracy: 0.8317 - val_loss: 0.3598 - val_binary_accuracy: 0.8355
# Epoch 18/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3639 - binary_accuracy: 0.8317 - val_loss: 0.3604 - val_binary_accuracy: 0.8342
# Epoch 19/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3622 - binary_accuracy: 0.8324 - val_loss: 0.3651 - val_binary_accuracy: 0.8305
# Epoch 20/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3613 - binary_accuracy: 0.8331 - val_loss: 0.3611 - val_binary_accuracy: 0.8343
# Epoch 21/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3590 - binary_accuracy: 0.8346 - val_loss: 0.3572 - val_binary_accuracy: 0.8363
# Epoch 22/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3579 - binary_accuracy: 0.8348 - val_loss: 0.3576 - val_binary_accuracy: 0.8358
# Epoch 23/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3561 - binary_accuracy: 0.8355 - val_loss: 0.3608 - val_binary_accuracy: 0.8336
# Epoch 24/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3551 - binary_accuracy: 0.8366 - val_loss: 0.3577 - val_binary_accuracy: 0.8346
# Epoch 25/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3547 - binary_accuracy: 0.8366 - val_loss: 0.3560 - val_binary_accuracy: 0.8349
# Epoch 26/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3541 - binary_accuracy: 0.8370 - val_loss: 0.3567 - val_binary_accuracy: 0.8356
# Epoch 27/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3528 - binary_accuracy: 0.8374 - val_loss: 0.3544 - val_binary_accuracy: 0.8366
# Epoch 28/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3508 - binary_accuracy: 0.8388 - val_loss: 0.3540 - val_binary_accuracy: 0.8378
# Epoch 29/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3491 - binary_accuracy: 0.8393 - val_loss: 0.3537 - val_binary_accuracy: 0.8362
# Epoch 30/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3492 - binary_accuracy: 0.8382 - val_loss: 0.3547 - val_binary_accuracy: 0.8371
# Epoch 31/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3483 - binary_accuracy: 0.8399 - val_loss: 0.3528 - val_binary_accuracy: 0.8367
# Epoch 32/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3466 - binary_accuracy: 0.8399 - val_loss: 0.3557 - val_binary_accuracy: 0.8355
# Epoch 33/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3464 - binary_accuracy: 0.8395 - val_loss: 0.3503 - val_binary_accuracy: 0.8383
# Epoch 34/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3443 - binary_accuracy: 0.8413 - val_loss: 0.3501 - val_binary_accuracy: 0.8392
# Epoch 35/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3442 - binary_accuracy: 0.8411 - val_loss: 0.3504 - val_binary_accuracy: 0.8386
# Epoch 36/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3438 - binary_accuracy: 0.8423 - val_loss: 0.3513 - val_binary_accuracy: 0.8401
# Epoch 37/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3430 - binary_accuracy: 0.8415 - val_loss: 0.3499 - val_binary_accuracy: 0.8403
# Epoch 38/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3415 - binary_accuracy: 0.8426 - val_loss: 0.3486 - val_binary_accuracy: 0.8396
# Epoch 39/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3401 - binary_accuracy: 0.8428 - val_loss: 0.3496 - val_binary_accuracy: 0.8401
# Epoch 40/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3404 - binary_accuracy: 0.8431 - val_loss: 0.3479 - val_binary_accuracy: 0.8402
# Epoch 41/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3391 - binary_accuracy: 0.8444 - val_loss: 0.3465 - val_binary_accuracy: 0.8422
# Epoch 42/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3378 - binary_accuracy: 0.8446 - val_loss: 0.3480 - val_binary_accuracy: 0.8417
# Epoch 43/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3372 - binary_accuracy: 0.8445 - val_loss: 0.3477 - val_binary_accuracy: 0.8413
# Epoch 44/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3365 - binary_accuracy: 0.8450 - val_loss: 0.3481 - val_binary_accuracy: 0.8419
# Epoch 45/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3359 - binary_accuracy: 0.8446 - val_loss: 0.3509 - val_binary_accuracy: 0.8396
# Epoch 46/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3356 - binary_accuracy: 0.8453 - val_loss: 0.3481 - val_binary_accuracy: 0.8413
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
